# %%
import sympy

# %%
sympy.sqrt(3)
# Out:
# sqrt(3)

# %%
sympy.sqrt(8)
# Out:
# 2*sqrt(2)

# %%
from sympy import symbols

# %%
x, y = symbols("x y")
expr = x + 2*y
expr
# Out:
# x + 2*y

# %%
x*expr
# Out:
# x*(x + 2*y)

# %%
from sympy import expand, factor
expanded_expr = expand(x*expr)
expanded_expr
# Out:
# x**2 + 2*x*y

# %%
factor(expanded_expr)
# Out:
# x*(x + 2*y)

# %%
from sympy import *

x, t, z, nu = symbols("x t z nu")

# %%
init_printing(use_unicode=True)

# %%
diff(sin(x) * exp(x), x)
# Out:
#  x           x
# ℯ ⋅sin(x) + ℯ ⋅cos(x)

# %%
integrate(exp(x) * sin(x) + exp(x) * cos(x), x)
# Out:
#  x
# ℯ ⋅sin(x)

# %%
integrate(sin(x**2), (x, -oo, oo))
# Out:
# √2⋅√π
# ─────
#   2

# %%
limit(sin(x) / x, x, 0)
# Out:
# 1

# %%
solve(x**2 - 2, x)
# Out:
# [-√2, √2]

# %%
y = Function("y")
dsolve(Eq(y(t).diff(t, t) - y(t), exp(t)), y(t))
# Out:
#            -t   ⎛     t⎞  t
# y(t) = C₂⋅ℯ   + ⎜C₁ + ─⎟⋅ℯ
#                 ⎝     2⎠

# %%
Matrix([[1,2],[2,2]]).eigenvals()
# Out:
# ⎧3   √17     3   √17   ⎫
# ⎨─ - ───: 1, ─ + ───: 1⎬
# ⎩2    2      2    2    ⎭

# %%
besselj(nu, z).rewrite(jn)
# Out:
# √2⋅√z⋅jn(ν - 1/2, z)
# ────────────────────
#          √π

# %%
latex(Integral(cos(x) ** 2, (x, 0, pi)))
# Out:
# '\\int\\limits_{0}^{\\pi} \\cos^{2}{\\left(x \\right)}\\, dx'

# %%
x = symbols("x")
x + 1
# Out:
# x + 1

# %%
x, y, z = symbols("x y z")

# %%
a, b = symbols("b a")

# %%
a
# Out:
# b

# %%
b
# Out:
# a

# %%
crazy = symbols("unrelated")

# %%
crazy + 1
# Out:
# unrelated + 1

# %%
x = symbols("x")
expr = x + 1
x = 2
expr
# Out:
# x + 1

# %% [markdown]
# Sympy中创建的任何表达式似乎都会直接保存在内存中，与torch和pandas中的逻辑略有不同，它们会倾向于创建一个view，或许是因为数据太占内存了不得不这么做？因为Sympy在docs中表示大部分python programs都是像他们这样的。

# %%
x = 'abc'
expr = x + 'def'
expr
# Out:
# 'abcdef'

# %%
x = 'ABC'
expr
# Out:
# 'abcdef'

# %%
x = symbols("x")
expr = x + 1
expr.subs(x, 2)
# Out:
# 3

# %% [markdown]
# 'expression.subs(variable, value)'可以直接输出结果，并且它不会改变expr本身，如果再次输出expr，得到的结果将会是原始结果，而非替换后的结果。

# %%
expr
# Out:
# x + 1

# %% [markdown]
# In Sympy, '==' represents structural equality testing, just as it does in standard python.

# %%
x + 1 == 4
# Out:
# False

# %%
a = (x + 1) ** 2
b = x**2 + 2 * x + 1
simplify(a - b)
# Out:
# 0

# %%
c = x**2 - 2 * x + 1
simplify(a - c)
# Out:
# 4⋅x

# %%
a = cos(x) ** 2 - sin(x) ** 2
b = cos(2 * x)
a.equals(b)
# Out:
# True

# %% [markdown]
# 从介绍上看，equal好像只会随机选取一个点来确认两个函数是否相等，不过应该不存在恰好选到两个函数的交点产生误判吧？不过应该也不排除这种可能。

# %%
True ^ False
# Out:
# True
